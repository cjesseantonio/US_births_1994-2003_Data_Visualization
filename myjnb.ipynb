# %%
import pandas as py

# %%
dataframe = py.read_csv('US_births_1994-2003_CDC_NCHS.csv')

# %%
year = dataframe[dataframe.year == 'Year']

# %%
births = dataframe[dataframe.births == 'Births']

# %%
dataframe.head()
# Out:
#    year  month  date_of_month  day_of_week  births
# 0  1994      1              1            6    8096
# 1  1994      1              2            7    7772
# 2  1994      1              3            1   10142
# 3  1994      1              4            2   11248
# 4  1994      1              5            3   11053

# %%
dataframe.iloc[0:5, [3]]
# Out:
#    day_of_week
# 0            6
# 1            7
# 2            1
# 3            2
# 4            3

# %%
import matplotlib.pyplot as plt

# %%
dataframe.plot( x = "births", kind = "line")

# %%
month = dataframe[dataframe.month == 'Month']

# %%
#us_births = py.concat([births, month])

# %%
dataframe.plot( x = "births", y = "month", kind = "line")

# %%
dateofmonth = dataframe[dataframe.date_of_month == 'Date of Month']

# %%
#us_births = py.concat([births, month, dateofmonth])

# %%
dataframe.plot( x = "month", y = "births", kind = "line")

# %%
dayofweek = dataframe[dataframe.day_of_week == 'Day of Week']

# %%
dataframe.plot( x = "month", y = "births", kind = "line")

# %%
us_births = py.concat([month,dateofmonth,dayofweek])

# %%
dataframe.plot( x = "year", y = "births", kind = "line")

# %%
dataframe.plot( x = "births", y = "year", kind = "line")

# %%
dataframe.plot( x = "year", y = "births", kind = "line")
